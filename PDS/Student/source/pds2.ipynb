# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/student.csv")

# %%
race_counts = df['race/ethnicity'].value_counts()
plt.figure(figsize=(8, 6))
race_counts.plot(kind='bar', color='skyblue')
plt.title('Race/Ethnicity Distribution')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
lunch_counts = df['lunch'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(lunch_counts, labels=lunch_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'])
plt.title('Lunch Type Distribution')
plt.show()

# %%
test_prep_counts = df['test preparation course'].value_counts()
plt.figure(figsize=(6, 6))
test_prep_counts.plot(kind='bar', color='lightblue')
plt.title('Test Preparation Course')
plt.xlabel('Course Completion')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(df['math score'], bins=20, color='skyblue', edgecolor='black')
plt.title('Math Score Distribution')
plt.xlabel('Score')
plt.ylabel('Count')

plt.subplot(1, 3, 2)
plt.hist(df['reading score'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Reading Score Distribution')
plt.xlabel('Score')
plt.ylabel('Count')

plt.subplot(1, 3, 3)
plt.hist(df['writing score'], bins=20, color='lightcoral', edgecolor='black')
plt.title('Writing Score Distribution')
plt.xlabel('Score')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
numeric_df = df[['math score', 'reading score', 'writing score']]
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
